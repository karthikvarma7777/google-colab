# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikvarma7777/google-colab/blob/main/weather_modeling_prediction_using_waterfall_model_approach_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the quadratic function
def quadratic(x, a=-0.8, b=0.5, c=8):
    return a * x**2 + b * x + c

# Define the stages of the Waterfall model
stages = ["Requirements", "Design", "Implementation", "Verification", "Maintenance"]

# Equally spaced x positions
x_positions = np.linspace(0, 3, len(stages))
y_positions = quadratic(x_positions)

# Plot the quadratic curve
x_curve = np.linspace(-0.5, 3.5, 500)
y_curve = quadratic(x_curve)

plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, linestyle="-", color="blue", label="Quadratic Curve")

# Add markers and waterfall-style connections
for i in range(len(stages)):
    if i > 0:
        # Horizontal segment
        plt.plot(
            [x_positions[i-1], x_positions[i]],
            [y_positions[i-1], y_positions[i-1]],
            color="blue",
            linewidth=2
        )
        # Vertical drop
        plt.plot(
            [x_positions[i], x_positions[i]],
            [y_positions[i-1], y_positions[i]],
            color="blue",
            linewidth=2
        )

    # Place markers
    plt.scatter(x_positions[i], y_positions[i], color="red", zorder=5)

    # Add labels
    plt.text(
        x_positions[i],
        y_positions[i] + 0.3,
        stages[i],
        ha="center",
        fontsize=10
    )

# Style the plot
plt.title("Waterfall Model Representation Using Quadratic Curve", fontsize=14)
plt.xlabel("Stages", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.axhline(0, color="black", linewidth=0.5, linestyle="--")
plt.axvline(0, color="black", linewidth=0.5, linestyle="--")
plt.legend()
plt.grid(True, linestyle=":", linewidth=0.5, alpha=0.7)
plt.show()
